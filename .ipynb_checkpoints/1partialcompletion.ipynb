# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import scipy.stats as stats
from scipy.stats import linregress
from scipy.stats import ttest_ind

# %% [markdown]
# 1.1

# %% [markdown]
# Načítanie všetkých súborov do DataFrames

# %%
df_profiles=pd.read_csv("data/profiles.csv",sep='\t')
df_processes=pd.read_csv("data/processes.csv",sep='\t')
df_devices=pd.read_csv("data/devices.csv",sep='\t')
df_connections = pd.read_csv("data/connections.csv", sep='\t')
df_profiles.head()
# Out:
#                         company                 imei              name  \
# 0                   Beck-Wright   863033069630348784  Gregory Santiago
# 1   Phillips, Dixon and Garrett  3590433799317661115        Tom Fisher
# 2                   Manning LLC   863033069630348826     Howard Garcia
# 3  Duarte, Campbell and Escobar   863033069630348263    Andrew Montoya
# 4                  Mcclure-Lutz   863033069630348131      Kelly Holder
#
#            ssn          registration               job  \
# 0  493-70-5760  05/04/2023, 00:00:00               NaN
# 1  598-97-2312            2020-05-09               NaN
# 2  383-26-6902           21 Aug 2021          Animator
# 3  556-81-7215  03/12/2023, 00:00:00               NaN
# 4  213-99-5419            2019-11-10  Textile designer
#
#                                   current_location        username  user_id  \
# 0  (Decimal('-10.6042995'), Decimal('-73.662677'))  zacharyclayton      474
# 1  (Decimal('-48.1319165'), Decimal('176.559852'))        dustin49     1307
# 2   (Decimal('44.7109925'), Decimal('-20.066520'))      davidstone     2255
# 3    (Decimal('30.7550255'), Decimal('81.033571'))      juliehayes     1319
# 4   (Decimal('-45.403474'), Decimal('120.541529'))         donna35     1883
#
#                     mail                                          residence  \
# 0   xraymond@hotmail.com                                                NaN
# 1    kevin90@hotmail.com  39281 Brianna Pines Suite 226\nMatthewchester,...
# 2  holmestommy@yahoo.com                                                NaN
# 3       john38@gmail.com  39662 Kenneth Locks Apt. 893\nNew Thomaston, N...
# 4    rebecca75@gmail.com                                                NaN
#
#   birthdate
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df_profiles['birthdate']=pd.to_datetime(df_profiles['birthdate'])
df_profiles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542 entries, 0 to 2541
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   company           2542 non-null   object
#  1   imei              2542 non-null   int64
#  2   name              2542 non-null   object
#  3   ssn               2542 non-null   object
#  4   registration      2542 non-null   object
#  5   job               763 non-null    object
#  6   current_location  2415 non-null   object
#  7   username          2542 non-null   object
#  8   user_id           2542 non-null   int64
#  9   mail              2542 non-null   object
#  10  residence         890 non-null    object
#  11  birthdate         1398 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 238.4+ KB

# %%
df_profiles.isnull().sum()
# Out:
# company                0
# imei                   0
# name                   0
# ssn                    0
# registration           0
# job                 1779
# current_location     127
# username               0
# user_id                0
# mail                   0
# residence           1652
# birthdate           1144
# dtype: int64

# %%
df_profiles.groupby(by=["company"]).head()
# Out:
#                            company                 imei              name  \
# 0                      Beck-Wright   863033069630348784  Gregory Santiago
# 1      Phillips, Dixon and Garrett  3590433799317661115        Tom Fisher
# 2                      Manning LLC   863033069630348826     Howard Garcia
# 3     Duarte, Campbell and Escobar   863033069630348263    Andrew Montoya
# 4                     Mcclure-Lutz   863033069630348131      Kelly Holder
# ...                            ...                  ...               ...
# 2537                  Williams Ltd  3590433799317661032     George Medina
# 2538                    Powell Ltd   359043379931766346     Tracy Johnson
# 2539                   Stanton PLC  3590433799317662378     Jesse Watkins
# 2540   Short, Jones and Stephenson  8630330696303481909       Joseph Hall
# 2541                   Johnson Inc   863033069630348776        Kari Owens
#
#               ssn          registration                             job  \
# 0     493-70-5760  05/04/2023, 00:00:00                             NaN
# 1     598-97-2312            2020-05-09                             NaN
# 2     383-26-6902           21 Aug 2021                        Animator
# 3     556-81-7215  03/12/2023, 00:00:00                             NaN
# 4     213-99-5419            2019-11-10                Textile designer
# ...           ...                   ...                             ...
# 2537  050-01-2295           06 Nov 2017  Investment banker, operational
# 2538  827-67-3184            2023-01-10    Investment banker, corporate
# 2539  739-24-9141            2022-06-16               Company secretary
# 2540  099-61-0802            2020/04/15                             NaN
# 2541  654-23-8285           13 Sep 2018                             NaN
#
#                                       current_location        username  \
# 0      (Decimal('-10.6042995'), Decimal('-73.662677'))  zacharyclayton
# 1      (Decimal('-48.1319165'), Decimal('176.559852'))        dustin49
# 2       (Decimal('44.7109925'), Decimal('-20.066520'))      davidstone
# 3        (Decimal('30.7550255'), Decimal('81.033571'))      juliehayes
# 4       (Decimal('-45.403474'), Decimal('120.541529'))         donna35
# ...                                                ...             ...
# 2537     (Decimal('-50.900289'), Decimal('68.921605'))  denniswilliams
# 2538     (Decimal('44.9009145'), Decimal('11.728548'))     johnsonryan
# 2539  (Decimal('-63.8649465'), Decimal('-104.002232'))      bellshelia
# 2540      (Decimal('33.743710'), Decimal('52.615341'))      paulnguyen
# 2541   (Decimal('-46.1919095'), Decimal('116.045817'))         megan50
#
#       user_id                   mail  \
# 0         474   xraymond@hotmail.com
# 1        1307    kevin90@hotmail.com
# 2        2255  holmestommy@yahoo.com
# 3        1319       john38@gmail.com
# 4        1883    rebecca75@gmail.com
# ...       ...                    ...
# 2537     2011      erika39@gmail.com
# 2538     2335    matthew99@gmail.com
# 2539     2220  woodsrobert@gmail.com
# 2540      654     upacheco@gmail.com
# 2541      386     rmoses@hotmail.com
#
#                                               residence  birthdate
# 0                                                   NaN        NaT
# 1     39281 Brianna Pines Suite 226\nMatthewchester,...        NaT
# 2                                                   NaN        NaT
# 3     39662 Kenneth Locks Apt. 893\nNew Thomaston, N...        NaT
# 4                                                   NaN        NaT
# ...                                                 ...        ...
# 2537  61121 Teresa Summit Apt. 744\nLauriemouth, NH ... 1931-04-04
# 2538         45179 Janice Haven\nSouth Taylor, AZ 10258        NaT
# 2539                                                NaN        NaT
# 2540                                                NaN        NaT
# 2541                                                NaN 1991-09-18
#
# [2542 rows x 12 columns]

# %% [markdown]
# fixing date and time

# %%
df_profiles['registration']=pd.to_datetime(df_profiles['registration'],format="mixed")
df_profiles.groupby(by=["company"]).head()
# Out:
#                            company                 imei              name  \
# 0                      Beck-Wright   863033069630348784  Gregory Santiago
# 1      Phillips, Dixon and Garrett  3590433799317661115        Tom Fisher
# 2                      Manning LLC   863033069630348826     Howard Garcia
# 3     Duarte, Campbell and Escobar   863033069630348263    Andrew Montoya
# 4                     Mcclure-Lutz   863033069630348131      Kelly Holder
# ...                            ...                  ...               ...
# 2537                  Williams Ltd  3590433799317661032     George Medina
# 2538                    Powell Ltd   359043379931766346     Tracy Johnson
# 2539                   Stanton PLC  3590433799317662378     Jesse Watkins
# 2540   Short, Jones and Stephenson  8630330696303481909       Joseph Hall
# 2541                   Johnson Inc   863033069630348776        Kari Owens
#
#               ssn registration                             job  \
# 0     493-70-5760   2023-05-04                             NaN
# 1     598-97-2312   2020-05-09                             NaN
# 2     383-26-6902   2021-08-21                        Animator
# 3     556-81-7215   2023-03-12                             NaN
# 4     213-99-5419   2019-11-10                Textile designer
# ...           ...          ...                             ...
# 2537  050-01-2295   2017-11-06  Investment banker, operational
# 2538  827-67-3184   2023-01-10    Investment banker, corporate
# 2539  739-24-9141   2022-06-16               Company secretary
# 2540  099-61-0802   2020-04-15                             NaN
# 2541  654-23-8285   2018-09-13                             NaN
#
#                                       current_location        username  \
# 0      (Decimal('-10.6042995'), Decimal('-73.662677'))  zacharyclayton
# 1      (Decimal('-48.1319165'), Decimal('176.559852'))        dustin49
# 2       (Decimal('44.7109925'), Decimal('-20.066520'))      davidstone
# 3        (Decimal('30.7550255'), Decimal('81.033571'))      juliehayes
# 4       (Decimal('-45.403474'), Decimal('120.541529'))         donna35
# ...                                                ...             ...
# 2537     (Decimal('-50.900289'), Decimal('68.921605'))  denniswilliams
# 2538     (Decimal('44.9009145'), Decimal('11.728548'))     johnsonryan
# 2539  (Decimal('-63.8649465'), Decimal('-104.002232'))      bellshelia
# 2540      (Decimal('33.743710'), Decimal('52.615341'))      paulnguyen
# 2541   (Decimal('-46.1919095'), Decimal('116.045817'))         megan50
#
#       user_id                   mail  \
# 0         474   xraymond@hotmail.com
# 1        1307    kevin90@hotmail.com
# 2        2255  holmestommy@yahoo.com
# 3        1319       john38@gmail.com
# 4        1883    rebecca75@gmail.com
# ...       ...                    ...
# 2537     2011      erika39@gmail.com
# 2538     2335    matthew99@gmail.com
# 2539     2220  woodsrobert@gmail.com
# 2540      654     upacheco@gmail.com
# 2541      386     rmoses@hotmail.com
#
#                                               residence  birthdate
# 0                                                   NaN        NaT
# 1     39281 Brianna Pines Suite 226\nMatthewchester,...        NaT
# 2                                                   NaN        NaT
# 3     39662 Kenneth Locks Apt. 893\nNew Thomaston, N...        NaT
# 4                                                   NaN        NaT
# ...                                                 ...        ...
# 2537  61121 Teresa Summit Apt. 744\nLauriemouth, NH ... 1931-04-04
# 2538         45179 Janice Haven\nSouth Taylor, AZ 10258        NaT
# 2539                                                NaN        NaT
# 2540                                                NaN        NaT
# 2541                                                NaN 1991-09-18
#
# [2542 rows x 12 columns]

# %% [markdown]
# #rename of disgustingly named collums for convenience todo - write normal comments
# #UPDATE : DO NOT RENAME COLUMNS , columns with same names like p.android.chrome appear in connections so if u rename it to android_connections in both tables (connections and processes) you will get problems with joining and its overall retarded to work with same names

# %%
#df_processes.rename(columns={col: col.replace("p.", "") for col in df_processes.columns if col.startswith("p.")}, inplace=True)
#df_processes.rename(columns={col: col.replace(".", "_") for col in df_processes.columns if "." in col }, inplace=True)
df_processes['ts']=pd.to_datetime(df_processes['ts'])
df_processes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15137 entries, 0 to 15136
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ts                          15137 non-null  datetime64[ns]
#  1   imei                        15137 non-null  int64
#  2   mwra                        15137 non-null  float64
#  3   p.android.chrome            15137 non-null  float64
#  4   p.android.externalstorage   15137 non-null  float64
#  5   p.android.gm                15137 non-null  float64
#  6   p.android.packageinstaller  15137 non-null  float64
#  7   p.android.settings          15137 non-null  float64
#  8   p.android.documentsui       15137 non-null  float64
#  9   p.system                    15137 non-null  float64
#  10  p.gms.persistent            15137 non-null  float64
#  11  p.android.gms               15137 non-null  float64
#  12  p.simulator                 15137 non-null  float64
#  13  p.inputmethod.latin         15137 non-null  float64
#  14  p.android.vending           15137 non-null  float64
#  15  p.notifier                  15137 non-null  float64
#  16  p.katana                    15137 non-null  float64
#  17  p.browser.provider          15137 non-null  float64
#  18  p.olauncher                 15137 non-null  float64
#  19  p.process.gapps             15137 non-null  float64
#  20  p.google                    15137 non-null  float64
#  21  p.android.defcontainer      15137 non-null  float64
#  22  p.dogalize                  15137 non-null  float64
# dtypes: datetime64[ns](1), float64(21), int64(1)
# memory usage: 2.7 MB

# %%
df_connections['ts']=pd.to_datetime(df_connections['ts'])
df_devices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2958 entries, 0 to 2957
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   latitude    2958 non-null   float64
#  1   longitude   2958 non-null   float64
#  2   store_name  2958 non-null   object
#  3   code        2957 non-null   object
#  4   location    2958 non-null   object
#  5   imei        2958 non-null   int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 138.8+ KB

# %%
df_devices.head()
# Out:
#    latitude  longitude  store_name code          location                 imei
# 0 -11.48472  -37.93278    Rio Real   BR     America/Bahia   863033069630348404
# 1  14.62072   74.83554       Sirsi   IN      Asia/Kolkata  8630330696303481412
# 2  54.84444   38.16694     Kashira   RU     Europe/Moscow  8630330696303481586
# 3  42.42510  -71.06616      Malden   US  America/New_York  3590433799317661503
# 4  37.17590  128.98890  T‚Äôaebaek   KR        Asia/Seoul  3590433799317661016

# %%
#df_connections.rename(columns={col: col.replace("c.", "") for col in df_connections.columns if col.startswith("c.")}, inplace=True)
#df_connections.rename(columns={col: col.replace(".", "_") for col in df_connections.columns if "." in col }, inplace=True)

df_connections.info()
#df_connections.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15137 entries, 0 to 15136
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ts                 15137 non-null  datetime64[ns]
#  1   imei               15137 non-null  int64
#  2   mwra               15137 non-null  float64
#  3   c.dogalize         15137 non-null  float64
#  4   c.android.youtube  15137 non-null  float64
#  5   c.katana           15137 non-null  float64
#  6   c.android.gm       15137 non-null  float64
#  7   c.android.chrome   15137 non-null  float64
#  8   c.raider           15137 non-null  float64
#  9   c.updateassist     15137 non-null  float64
#  10  c.android.vending  15137 non-null  float64
#  11  c.UCMobile.intl    15137 non-null  float64
#  12  c.UCMobile.x86     15137 non-null  float64
# dtypes: datetime64[ns](1), float64(11), int64(1)
# memory usage: 1.5 MB

# %%
df_connections.head()
# Out:
#                    ts                 imei  mwra  c.dogalize  \
# 0 2018-05-05 10:00:00   359043379931766817   0.0    14.86100
# 1 2018-05-05 10:01:00  8630330696303481313   1.0    14.83612
# 2 2018-05-05 10:02:00  8630330696303482485   1.0    16.72953
# 3 2018-05-05 10:03:00  8630330696303481628   0.0     8.01110
# 4 2018-05-05 10:04:00   359043379931766957   0.0    11.61620
#
#    c.android.youtube  c.katana  c.android.gm  c.android.chrome  c.raider  \
# 0           11.58414  12.03004      10.27425          10.91841  38.44506
# 1           12.34182  11.04896       9.89308          11.44850  53.51368
# 2           12.50429  10.10484      16.81150          11.10686  44.37810
# 3           14.99371  14.78679      11.08389           6.38690  33.49077
# 4           12.77182  10.49031      12.13535          13.94101  61.36395
#
#    c.updateassist  c.android.vending  c.UCMobile.intl  c.UCMobile.x86
# 0        80.02544           26.10909         67.13184        93.30543
# 1        16.38711           63.61596         53.85173        98.59528
# 2        80.51528           79.91808         41.15915        86.40680
# 3        20.93570           45.73413         93.57377        13.77874
# 4        25.23605            2.93423         92.11111        44.58123

# %%
df_connections[df_connections.duplicated(keep='last')].shape[0]
# Out:
# 179

# %% [markdown]
# #So if ya have job ur more likely to have residence uwu (im really not sure tf am i supposed to do here, I'd much rather theey give me input and ouput)
# #important attribute #1 residence ,#2  job

# %%
unemployed_count=df_profiles[df_profiles['job'].isnull() &df_profiles['residence'].isnull()].shape[0]
employed_count=df_profiles[df_profiles['job'].notnull() &df_profiles['residence'].isnull()].shape[0]
print("Number of users without jobs and without resudenci : "+str(unemployed_count))
# Out:
# Number of users without jobs and without resudenci : 1164

# %%
plt.bar(["Unemployed (No Residence)","Employed (No Residence)"],[unemployed_count/df_profiles.shape[0],employed_count/df_profiles.shape[0]])
plt.title("Employment Status vs Residenc")
plt.show()

# %% [markdown]
# checking number if number of unemployed people grows with age
# #third important attribute , year

# %%
#copy sorted df_profiles
df_profiles_sorted=df_profiles[df_profiles['job'].isnull()].sort_values(by='birthdate')
#keep only yaer
df_profiles_sorted['birthdate']=pd.to_datetime(df_profiles_sorted['birthdate']).dt.year
#create graph
plt.plot(df_profiles_sorted.groupby(by=['birthdate'])['birthdate'].count())
#make a funny line with linegress since idk what to do 
res = linregress(df_profiles_sorted.groupby(by=['birthdate'])['birthdate'].count().index, df_profiles_sorted.groupby('birthdate')['birthdate'].count())
plt.plot(df_profiles_sorted['birthdate'], res.intercept + res.slope * df_profiles_sorted['birthdate'])

# %% [markdown]
# #important attributes 4,5,6,7,8,9 :

# %%
df_connections[3:9].describe()
# Out:
#                         ts          imei      mwra  c.dogalize  \
# count                    6  6.000000e+00  6.000000    6.000000
# mean   2018-05-05 10:05:30  5.117250e+18  0.666667   12.235760
# min    2018-05-05 10:03:00  3.590434e+17  0.000000    8.011100
# 25%    2018-05-05 10:04:15  1.544883e+18  0.250000   10.565008
# 50%    2018-05-05 10:05:30  6.110382e+18  1.000000   11.882325
# 75%    2018-05-05 10:06:45  8.630331e+18  1.000000   14.125518
# max    2018-05-05 10:08:00  8.630331e+18  1.000000   16.639660
# std                    NaN  4.002381e+18  0.516398    3.105315
#
#        c.android.youtube   c.katana  c.android.gm  c.android.chrome  \
# count           6.000000   6.000000      6.000000          6.000000
# mean           11.383520  12.470082     10.981762         10.971648
# min             8.442420  10.438610      5.538490          6.386900
# 25%             8.932005  10.714057      9.797235          9.501743
# 50%            10.909100  12.024745     11.120595         11.605225
# 75%            13.807638  14.256140     11.890837         13.019517
# max            14.993710  15.055290     16.607190         13.941010
# std             2.930562   2.064521      3.612472          2.861703
#
#         c.raider  c.updateassist  c.android.vending  c.UCMobile.intl  \
# count   6.000000        6.000000           6.000000         6.000000
# mean   45.601110       52.711898          40.524497        51.684948
# min    28.062320       20.935700           2.934230         1.609560
# 25%    35.796518       27.235200           7.086577        29.703003
# 50%    44.841305       44.773080          28.847460        49.903400
# 75%    57.497470       79.759260          73.818135        81.588368
# max    61.363950       92.978970          93.876520        93.573770
# std    13.786123       31.603482          40.376550        36.674812
#
#        c.UCMobile.x86
# count        6.000000
# mean        45.332820
# min         13.778740
# 25%         29.224833
# 50%         39.069395
# 75%         64.366973
# max         81.336580
# std         26.061847

# %%
df_connections.hist(column=df_connections.columns[3:9],figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'c.dogalize'}>,
#         <Axes: title={'center': 'c.android.youtube'}>],
#        [<Axes: title={'center': 'c.katana'}>,
#         <Axes: title={'center': 'c.android.gm'}>],
#        [<Axes: title={'center': 'c.android.chrome'}>,
#         <Axes: title={'center': 'c.raider'}>]], dtype=object)

# %% [markdown]
# #important attributes 10 11 12

# %%
df_processes[['p.android.gm','p.android.settings','p.system']].describe()
# Out:
#        p.android.gm  p.android.settings      p.system
# count  15137.000000        15137.000000  15137.000000
# mean      12.220034           13.360130     13.300370
# std        2.417076            2.621851      2.773015
# min        3.492160            2.936040      2.605000
# 25%       10.462840           11.692900     11.333590
# 50%       11.990460           13.660240     13.335930
# 75%       13.935790           15.212220     15.291500
# max       21.005110           21.756040     23.130130

# %%
df_processes.hist(column=['p.android.gm','p.android.settings','p.system'])
# Out:
# array([[<Axes: title={'center': 'p.android.gm'}>,
#         <Axes: title={'center': 'p.android.settings'}>],
#        [<Axes: title={'center': 'p.system'}>, <Axes: >]], dtype=object)

# %% [markdown]
# 1.1 C | nemám tušenie čo som sem mal dať ani prečo porovnal som nakoniec nejaké veci s velkou šancou na koreláciu, čo basically znamená skoro nulové info

# %%
df_con_pro = pd.merge(df_connections, df_processes, on=['imei', 'ts'], how='inner')

plt.figure(figsize=(8, 6))
sns.scatterplot(x=df_con_pro['c.android.vending'], y=df_con_pro['p.android.vending'])
plt.title('Play Store: Connections vs Processes')
plt.xlabel('Play Store Connections')
plt.ylabel('Play Store Processes')
plt.show()

play_store_corr = df_con_pro['c.android.vending'].corr(df_con_pro['p.android.vending'], method='pearson')
print(f'Correlation between Play Store Connections and Processes: {play_store_corr}')
# Out:
# Correlation between Play Store Connections and Processes: -0.009170443716403373

# %%
chrome_corr = df_con_pro['c.android.chrome'].corr(df_con_pro['p.android.chrome'], method='pearson')
print(f'Correlation between Chrome Connections and Chrome Processes: {chrome_corr}')
# Out:
# Correlation between Chrome Connections and Chrome Processes: -0.2197277738550875

# %%
merged_profiles_devices = pd.merge(df_profiles, df_devices, on='imei', how='inner')

plt.figure(figsize=(10, 6))
sns.scatterplot(x=merged_profiles_devices['latitude'], y=merged_profiles_devices['longitude'])
plt.title('Geolocation (Latitude, Longitude) vs Current Location')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.show()

# %%
#Possible missing values or other problem

#plt.figure(figsize=(8, 6))
#sns.scatterplot(x=df_con_pro['c.android.gms'], y=df_con_pro['p.android.gms'])
#plt.title('Google Services: Connections vs Processes')
#plt.xlabel('Google Services Connections')
#plt.ylabel('Google Services Processes')
#plt.show()


#google_corr = df_con_pro['c.android.gms'].corr(df_con_pro['p.android.gms'], method='pearson')
#print(f'Correlation between Google Services Connections and Processes: {google_corr}')

# %%
merged_profiles_connections = pd.merge(df_profiles, df_connections, on='imei', how='inner')

top_jobs = merged_profiles_connections.groupby('job')['c.android.youtube'].sum().nlargest(10).index

top_job_data = merged_profiles_connections[merged_profiles_connections['job'].isin(top_jobs)]

plt.figure(figsize=(10, 6))
sns.barplot(x='job', y='c.android.youtube', data=top_job_data, estimator=sum)
plt.title('YouTube Connections vs Top Job Types')
plt.xlabel('Job Type')
plt.ylabel('Total YouTube Connections')
plt.xticks(rotation=45)
plt.show()

# %%
merged_connections_devices = pd.merge(df_connections, df_devices, on='imei', how='inner')

plt.figure(figsize=(10, 6))
sns.scatterplot(x=merged_connections_devices['latitude'], y=merged_connections_devices['longitude'], size=merged_connections_devices['c.android.youtube'], legend=False)
plt.title('Geolocation (Latitude, Longitude) vs YouTube Connections')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.show()

# %% [markdown]
# 1.1 D       Connections

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='mwra', y='c.dogalize', data=df_connections)

plt.title('Box Plot of c.dogalize vs mwra', fontsize=16)
plt.xlabel('mwra', fontsize=12)
plt.ylabel('c.dogalize', fontsize=12)

plt.show()

group1 = df_connections[df_connections['mwra'] == 0]['c.dogalize']
group2 = df_connections[df_connections['mwra'] == 1]['c.dogalize']
t_stat, p_value = stats.ttest_ind(group1, group2)
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: -35.770977903342484, P-value: 4.313207181404798e-269

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='mwra', y='c.android.chrome', data=df_connections)

plt.title('Box Plot of c.android.chrome vs mwra', fontsize=16)
plt.xlabel('mwra', fontsize=12)
plt.ylabel('c.android.chrome', fontsize=12)

plt.show()

group1 = df_connections[df_connections['mwra'] == 0]['c.android.chrome']
group2 = df_connections[df_connections['mwra'] == 1]['c.android.chrome']
t_stat, p_value = stats.ttest_ind(group1, group2)
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: 40.73559524318752, P-value: 0.0

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='mwra', y='c.android.gm', data=df_connections)

plt.title('Box Plot of android.gm vs mwra', fontsize=16)
plt.xlabel('mwra', fontsize=12)
plt.ylabel('android.gm', fontsize=12)

plt.show()

group1 = df_connections[df_connections['mwra'] == 0]['c.android.gm']
group2 = df_connections[df_connections['mwra'] == 1]['c.android.gm']
t_stat, p_value = stats.ttest_ind(group1, group2)
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: -32.79850369126001, P-value: 5.42277842024909e-228

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='mwra', y='p.android.externalstorage', data=df_processes)

plt.title('Box Plot of p.android.externalstorage vs mwra', fontsize=16)
plt.xlabel('mwra', fontsize=12)
plt.ylabel('p.android.externalstorage', fontsize=12)

plt.show()

group1 = df_connections[df_connections['mwra'] == 0]['c.android.youtube']
group2 = df_connections[df_connections['mwra'] == 1]['c.android.youtube']
t_stat, p_value = stats.ttest_ind(group1, group2)
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: -0.1648860551426131, P-value: 0.8690358705819591

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='mwra', y='p.android.documentsui', data=df_processes)

plt.title('Box Plot of p.android.documentsui vs mwra', fontsize=16)
plt.xlabel('mwra', fontsize=12)
plt.ylabel('p.android.documentsui', fontsize=12)

plt.show()

group1 = df_processes[df_processes['mwra'] == 0]['p.android.documentsui']
group2 = df_processes[df_processes['mwra'] == 1]['p.android.documentsui']
t_stat, p_value = stats.ttest_ind(group1, group2)
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: -39.42305688518544, P-value: 0.0

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='mwra', y='p.android.settings', data=df_processes)

plt.title('Box Plot of p.android.settings vs mwra', fontsize=16)
plt.xlabel('mwra', fontsize=12)
plt.ylabel('p.android.settings', fontsize=12)

plt.show()

group1 = df_processes[df_processes['mwra'] == 0]['p.android.settings']
group2 = df_processes[df_processes['mwra'] == 1]['p.android.settings']
t_stat, p_value = stats.ttest_ind(group1, group2)
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: 35.25941205831529, P-value: 8.39396720270154e-262

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='mwra', y='p.android.externalstorage', data=df_processes)

plt.title('Box Plot of p.android.externalstorage vs mwra', fontsize=16)
plt.xlabel('mwra', fontsize=12)
plt.ylabel('p.android.externalstorage', fontsize=12)

plt.show()
group1 = df_processes[df_processes['mwra'] == 0]['p.android.externalstorage']
group2 = df_processes[df_processes['mwra'] == 1]['p.android.externalstorage']
t_stat, p_value = stats.ttest_ind(group1, group2)
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: 37.98981838751341, P-value: 1.0102983519186332e-301

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='mwra', y='p.system', data=df_processes)

plt.title('Box Plot of p.system vs mwra', fontsize=16)
plt.xlabel('mwra', fontsize=12)
plt.ylabel('p.system', fontsize=12)

plt.show()
group1 = df_processes[df_processes['mwra'] == 0]['p.system']
group2 = df_processes[df_processes['mwra'] == 1]['p.system']
t_stat, p_value = stats.ttest_ind(group1, group2)
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: -73.32040936466328, P-value: 0.0
